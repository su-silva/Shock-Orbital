# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import os

# %%
# Configuration
NASA_API_KEY = "YOUR_API_KEY_HERE"  # Your API Key here
BASE_URL = "https://api.nasa.gov/neo/rest/v1"

def get_10_years_data(api_key, years=10):
    """
    Gets asteroid data for the last X years by iterating through 7-day periods
    """
    print(f"STARTING EXTRACTION OF {years} YEARS OF ASTEROID DATA")
    print("=" * 60)
    
    end_date = datetime.now()
    start_date = end_date - timedelta(days=years*365)
    
    print(f"Period: {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")
    
    all_asteroids = []
    current_date = start_date
    total_requests = 0
    
    while current_date < end_date:
        # Calculate period end date (7 days later)
        period_end_date = min(current_date + timedelta(days=7), end_date)
        
        # Format dates for API
        start_date_str = current_date.strftime('%Y-%m-%d')
        end_date_str = period_end_date.strftime('%Y-%m-%d')
        
        print(f" Getting data: {start_date_str} to {end_date_str}")
        
        try:
            url = f"{BASE_URL}/feed?start_date={start_date_str}&end_date={end_date_str}&api_key={api_key}"
            response = requests.get(url)
            response.raise_for_status()
            data = response.json()
            
            # Extract asteroids from all days in this period
            period_asteroids = []
            for date, objects in data.get('near_earth_objects', {}).items():
                for asteroid in objects:
                    # Add approach date to each asteroid
                    asteroid['close_approach_date'] = date
                    period_asteroids.append(asteroid)
            
            all_asteroids.extend(period_asteroids)
            total_requests += 1
            
            print(f"Period {start_date_str}: {len(period_asteroids)} approaches")
            
            # Small pause to avoid API rate limiting
            time.sleep(0.5)
            
        except requests.exceptions.RequestException as e:
            print(f"Error in period {start_date_str}: {e}")
            continue
        
        # Move to next period
        current_date = period_end_date
    
    print(f"\nEXTRACTION COMPLETED:")
    print(f"   • Total periods processed: {total_requests}")
    print(f"   • Total unique approaches: {len(all_asteroids)}")
    
    return all_asteroids

def create_historical_dataframe(asteroid_data):
    """
    Creates an enriched DataFrame with historical data
    """
    if not asteroid_data:
        print("No data obtained to create DataFrame")
        return pd.DataFrame()
    
    print(f"\nProcessing {len(asteroid_data)} approaches...")
    
    processed_data = []
    
    for asteroid in asteroid_data:
        try:
            # BASIC INFORMATION
            base_data = {
                'id': asteroid.get('id'),
                'neo_reference_id': asteroid.get('neo_reference_id'),
                'name': asteroid.get('name'),
                'cleaned_name': asteroid.get('name', '').replace('(', '').replace(')', ''),
                'nasa_jpl_url': asteroid.get('nasa_jpl_url'),
                'is_hazardous': asteroid.get('is_potentially_hazardous_asteroid', False),
                'approach_date': asteroid.get('close_approach_date'),
                'absolute_magnitude': asteroid.get('absolute_magnitude_h'),
            }
            
            # ESTIMATED DIAMETERS IN DIFFERENT UNITS
            estimated_diameter = asteroid.get('estimated_diameter', {})
            units = ['kilometers', 'meters', 'miles', 'feet']
            
            for unit in units:
                if unit in estimated_diameter:
                    base_data.update({
                        f'diameter_min_{unit}': estimated_diameter[unit].get('estimated_diameter_min'),
                        f'diameter_max_{unit}': estimated_diameter[unit].get('estimated_diameter_max'),
                        f'diameter_avg_{unit}': (
                            estimated_diameter[unit].get('estimated_diameter_min', 0) + 
                            estimated_diameter[unit].get('estimated_diameter_max', 0)
                        ) / 2
                    })
            
            # CLOSE APPROACH DATA (more detailed)
            close_approaches = asteroid.get('close_approach_data', [])
            if close_approaches:
                # Take the first approach (which matches the date)
                approach = close_approaches[0]
                base_data.update({
                    'full_approach_date': approach.get('close_approach_date_full'),
                    'approach_epoch': approach.get('epoch_date_close_approach'),
                    'relative_velocity_kms': approach.get('relative_velocity', {}).get('kilometers_per_second'),
                    'relative_velocity_kmh': approach.get('relative_velocity', {}).get('kilometers_per_hour'),
                    'relative_velocity_mph': approach.get('relative_velocity', {}).get('miles_per_hour'),
                    'miss_distance_km': approach.get('miss_distance', {}).get('kilometers'),
                    'miss_distance_lunar': approach.get('miss_distance', {}).get('lunar'),
                    'miss_distance_astronomical': approach.get('miss_distance', {}).get('astronomical'),
                    'orbiting_body': approach.get('orbiting_body')
                })
            
            processed_data.append(base_data)
            
        except Exception as e:
            print(f"Error processing asteroid {asteroid.get('id')}: {e}")
            continue
    
    # Create DataFrame
    df = pd.DataFrame(processed_data)
    
    # Convert date columns
    if 'approach_date' in df.columns:
        df['approach_date'] = pd.to_datetime(df['approach_date'], errors='coerce')
    
    # Convert numeric columns
    numeric_columns = [
        'absolute_magnitude', 'relative_velocity_kms', 'miss_distance_km',
        'miss_distance_lunar', 'miss_distance_astronomical'
    ]
    
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    
    print(f"Historical DataFrame created with {len(df)} rows and {len(df.columns)} columns")
    return df

def save_dataset(df, filename_prefix="asteroids_10_years"):
    """
    Saves the dataset to a CSV file with timestamp
    """
    if df.empty:
        print("No data to save")
        return None
    
    timestamp = datetime.now().strftime('%Y%m%d_%H%M')
    filename = f"{filename_prefix}_{timestamp}.csv"
    
    df.to_csv(filename, index=False, encoding='utf-8')
    
    size_mb = os.path.getsize(filename) / 1024 / 1024
    print(f"Dataset saved in: {filename}")
    print(f"File size: {size_mb:.2f} MB")
    print(f"Dimensions: {df.shape[0]:,} rows × {df.shape[1]} columns")
    
    return filename

# MAIN EXECUTION - EXTRACTION ONLY
if __name__ == "__main__":
    print("CREATING ASTEROID DATABASE (10 YEARS)")
    print("=" * 70)
    
    # 1. Get historical data
    asteroid_data = get_10_years_data(NASA_API_KEY, years=10)
    
    if asteroid_data:
        # 2. Create historical DataFrame
        historical_df = create_historical_dataframe(asteroid_data)
        
        if not historical_df.empty:
            # 3. Save dataset
            saved_file = save_dataset(historical_df)
            
            if saved_file:
                print(f"\nDATABASE SUCCESSFULLY CREATED!")
                print(f"File: {saved_file}")
                print(f"Total approaches: {len(historical_df):,}")
                print(f"Period covered: {historical_df['approach_date'].min()} to {historical_df['approach_date'].max()}")
            else:
                print("Error saving file")
    else:
        print("Could not get historical data from NASA API")
# Out:
# CREATING ASTEROID DATABASE (10 YEARS)
# ======================================================================
# STARTING EXTRACTION OF 10 YEARS OF ASTEROID DATA
# ============================================================
# Period: 2015-10-08 to 2025-10-05
#  Getting data: 2015-10-08 to 2015-10-15
# Period 2015-10-08: 121 approaches
#  Getting data: 2015-10-15 to 2015-10-22
# Period 2015-10-15: 122 approaches
#  Getting data: 2015-10-22 to 2015-10-29
# Period 2015-10-22: 127 approaches
#  Getting data: 2015-10-29 to 2015-11-05
# Period 2015-10-29: 144 approaches
#  Getting data: 2015-11-05 to 2015-11-12
# Period 2015-11-05: 148 approaches
#  Getting data: 2015-11-12 to 2015-11-19
# Period 2015-11-12: 113 approaches
#  Getting data: 2015-11-19 to 2015-11-26
# Period 2015-11-19: 117 approaches
#  Getting data: 2015-11-26 to 2015-12-03
# Period 2015-11-26: 128 approaches
#  Getting data: 2015-12-03 to 2015-12-10
# Period 2015-12-03: 147 approaches
#  Getting data: 2015-12-10 to 2015-12-17
# Period 2015-12-10: 113 approaches
#  Getting data: 2015-12-17 to 2015-12-24
# Period 2015-12-17: 107 approaches
#  Getting data: 2015-12-24 to 2015-12-31
# Period 2015-12-24: 123 approaches
#  Getting data: 2015-12-31 to 2016-01-07
# Period 2015-12-31: 109 approaches
#  Getting data: 2016-01-07 to 2016-01-14
# Period 2016-01-07: 102 approaches
#  Getting data: 2016-01-14 to 2016-01-21
# Period 2016-01-14: 100 approaches
#  Getting data: 2016-01-21 to 2016-01-28
# Period 2016-01-21: 121 approaches
#  Getting data: 2016-01-28 to 2016-02-04
# Period 2016-01-28: 131 approaches
#  Getting data: 2016-02-04 to 2016-02-11
# Period 2016-02-04: 159 approaches
#  Getting data: 2016-02-11 to 2016-02-18
# Period 2016-02-11: 127 approaches
#  Getting data: 2016-02-18 to 2016-02-25
# Period 2016-02-18: 137 approaches
#  Getting data: 2016-02-25 to 2016-03-03
# Period 2016-02-25: 132 approaches
#  Getting data: 2016-03-03 to 2016-03-10
# Period 2016-03-03: 130 approaches
#  Getting data: 2016-03-10 to 2016-03-17
# Period 2016-03-10: 139 approaches
#  Getting data: 2016-03-17 to 2016-03-24
# Period 2016-03-17: 111 approaches
#  Getting data: 2016-03-24 to 2016-03-31
# Period 2016-03-24: 136 approaches
#  Getting data: 2016-03-31 to 2016-04-07
# Period 2016-03-31: 129 approaches
#  Getting data: 2016-04-07 to 2016-04-14
# Period 2016-04-07: 129 approaches
#  Getting data: 2016-04-14 to 2016-04-21
# Period 2016-04-14: 126 approaches
#  Getting data: 2016-04-21 to 2016-04-28
# Period 2016-04-21: 132 approaches
#  Getting data: 2016-04-28 to 2016-05-05
# Period 2016-04-28: 132 approaches
#  Getting data: 2016-05-05 to 2016-05-12
# Period 2016-05-05: 106 approaches
#  Getting data: 2016-05-12 to 2016-05-19
# Period 2016-05-12: 108 approaches
#  Getting data: 2016-05-19 to 2016-05-26
# Period 2016-05-19: 91 approaches
#  Getting data: 2016-05-26 to 2016-06-02
# Period 2016-05-26: 106 approaches
#  Getting data: 2016-06-02 to 2016-06-09
# Period 2016-06-02: 100 approaches
#  Getting data: 2016-06-09 to 2016-06-16
# Period 2016-06-09: 106 approaches
#  Getting data: 2016-06-16 to 2016-06-23
# Period 2016-06-16: 100 approaches
#  Getting data: 2016-06-23 to 2016-06-30
# Period 2016-06-23: 79 approaches
#  Getting data: 2016-06-30 to 2016-07-07
# Period 2016-06-30: 93 approaches
#  Getting data: 2016-07-07 to 2016-07-14
# Period 2016-07-07: 85 approaches
#  Getting data: 2016-07-14 to 2016-07-21
# Period 2016-07-14: 105 approaches
#  Getting data: 2016-07-21 to 2016-07-28
# Period 2016-07-21: 105 approaches
#  Getting data: 2016-07-28 to 2016-08-04
# Period 2016-07-28: 109 approaches
#  Getting data: 2016-08-04 to 2016-08-11
# Period 2016-08-04: 105 approaches
#  Getting data: 2016-08-11 to 2016-08-18
# Period 2016-08-11: 104 approaches
#  Getting data: 2016-08-18 to 2016-08-25
# Period 2016-08-18: 102 approaches
#  Getting data: 2016-08-25 to 2016-09-01
# Period 2016-08-25: 123 approaches
#  Getting data: 2016-09-01 to 2016-09-08
# Period 2016-09-01: 131 approaches
#  Getting data: 2016-09-08 to 2016-09-15
# Period 2016-09-08: 148 approaches
#  Getting data: 2016-09-15 to 2016-09-22
# Period 2016-09-15: 118 approaches
#  Getting data: 2016-09-22 to 2016-09-29
# Period 2016-09-22: 135 approaches
#  Getting data: 2016-09-29 to 2016-10-06
# Period 2016-09-29: 146 approaches
#  Getting data: 2016-10-06 to 2016-10-13
# Period 2016-10-06: 165 approaches
#  Getting data: 2016-10-13 to 2016-10-20
# Period 2016-10-13: 141 approaches
#  Getting data: 2016-10-20 to 2016-10-27
# Period 2016-10-20: 156 approaches
#  Getting data: 2016-10-27 to 2016-11-03
# Period 2016-10-27: 145 approaches
#  Getting data: 2016-11-03 to 2016-11-10
# Period 2016-11-03: 138 approaches
#  Getting data: 2016-11-10 to 2016-11-17
# Period 2016-11-10: 147 approaches
#  Getting data: 2016-11-17 to 2016-11-24
# Period 2016-11-17: 117 approaches
#  Getting data: 2016-11-24 to 2016-12-01
# Period 2016-11-24: 133 approaches
#  Getting data: 2016-12-01 to 2016-12-08
# Period 2016-12-01: 123 approaches
#  Getting data: 2016-12-08 to 2016-12-15
# Period 2016-12-08: 96 approaches
#  Getting data: 2016-12-15 to 2016-12-22
# Period 2016-12-15: 115 approaches
#  Getting data: 2016-12-22 to 2016-12-29
# Period 2016-12-22: 104 approaches
#  Getting data: 2016-12-29 to 2017-01-05
# Period 2016-12-29: 107 approaches
#  Getting data: 2017-01-05 to 2017-01-12
# Period 2017-01-05: 105 approaches
#  Getting data: 2017-01-12 to 2017-01-19
# Period 2017-01-12: 115 approaches
#  Getting data: 2017-01-19 to 2017-01-26
# Period 2017-01-19: 114 approaches
#  Getting data: 2017-01-26 to 2017-02-02
# Period 2017-01-26: 130 approaches
#  Getting data: 2017-02-02 to 2017-02-09
# Period 2017-02-02: 129 approaches
#  Getting data: 2017-02-09 to 2017-02-16
# Period 2017-02-09: 106 approaches
#  Getting data: 2017-02-16 to 2017-02-23
# Period 2017-02-16: 138 approaches
#  Getting data: 2017-02-23 to 2017-03-02
# Period 2017-02-23: 145 approaches
#  Getting data: 2017-03-02 to 2017-03-09
# Period 2017-03-02: 149 approaches
#  Getting data: 2017-03-09 to 2017-03-16
# Period 2017-03-09: 119 approaches
#  Getting data: 2017-03-16 to 2017-03-23
# Period 2017-03-16: 143 approaches
#  Getting data: 2017-03-23 to 2017-03-30
# Period 2017-03-23: 138 approaches
#  Getting data: 2017-03-30 to 2017-04-06
# Period 2017-03-30: 141 approaches
#  Getting data: 2017-04-06 to 2017-04-13
# Period 2017-04-06: 132 approaches
#  Getting data: 2017-04-13 to 2017-04-20
# Period 2017-04-13: 118 approaches
#  Getting data: 2017-04-20 to 2017-04-27
# Period 2017-04-20: 126 approaches
#  Getting data: 2017-04-27 to 2017-05-04
# Period 2017-04-27: 106 approaches
#  Getting data: 2017-05-04 to 2017-05-11
# Period 2017-05-04: 101 approaches
#  Getting data: 2017-05-11 to 2017-05-18
# Period 2017-05-11: 102 approaches
#  Getting data: 2017-05-18 to 2017-05-25
# Period 2017-05-18: 109 approaches
#  Getting data: 2017-05-25 to 2017-06-01
# Period 2017-05-25: 113 approaches
#  Getting data: 2017-06-01 to 2017-06-08
# Period 2017-06-01: 98 approaches
#  Getting data: 2017-06-08 to 2017-06-15
# Period 2017-06-08: 91 approaches
#  Getting data: 2017-06-15 to 2017-06-22
# Period 2017-06-15: 102 approaches
#  Getting data: 2017-06-22 to 2017-06-29
# Period 2017-06-22: 93 approaches
#  Getting data: 2017-06-29 to 2017-07-06
# Period 2017-06-29: 117 approaches
#  Getting data: 2017-07-06 to 2017-07-13
# Period 2017-07-06: 104 approaches
#  Getting data: 2017-07-13 to 2017-07-20
# Period 2017-07-13: 108 approaches
#  Getting data: 2017-07-20 to 2017-07-27
# Period 2017-07-20: 107 approaches
#  Getting data: 2017-07-27 to 2017-08-03
# Period 2017-07-27: 106 approaches
#  Getting data: 2017-08-03 to 2017-08-10
# Period 2017-08-03: 115 approaches
#  Getting data: 2017-08-10 to 2017-08-17
# Period 2017-08-10: 139 approaches
#  Getting data: 2017-08-17 to 2017-08-24
# Period 2017-08-17: 111 approaches
#  Getting data: 2017-08-24 to 2017-08-31
# Period 2017-08-24: 123 approaches
#  Getting data: 2017-08-31 to 2017-09-07
# Period 2017-08-31: 141 approaches
#  Getting data: 2017-09-07 to 2017-09-14
# Period 2017-09-07: 143 approaches
#  Getting data: 2017-09-14 to 2017-09-21
# Period 2017-09-14: 142 approaches
#  Getting data: 2017-09-21 to 2017-09-28
# Period 2017-09-21: 149 approaches
#  Getting data: 2017-09-28 to 2017-10-05
# Period 2017-09-28: 155 approaches
#  Getting data: 2017-10-05 to 2017-10-12
# Period 2017-10-05: 165 approaches
#  Getting data: 2017-10-12 to 2017-10-19
# Period 2017-10-12: 177 approaches
#  Getting data: 2017-10-19 to 2017-10-26
# Period 2017-10-19: 194 approaches
#  Getting data: 2017-10-26 to 2017-11-02
# Period 2017-10-26: 153 approaches
#  Getting data: 2017-11-02 to 2017-11-09
# Period 2017-11-02: 126 approaches
#  Getting data: 2017-11-09 to 2017-11-16
# Period 2017-11-09: 150 approaches
#  Getting data: 2017-11-16 to 2017-11-23
# Period 2017-11-16: 163 approaches
#  Getting data: 2017-11-23 to 2017-11-30
# Period 2017-11-23: 140 approaches
#  Getting data: 2017-11-30 to 2017-12-07
# Period 2017-11-30: 115 approaches
#  Getting data: 2017-12-07 to 2017-12-14
# Period 2017-12-07: 114 approaches
#  Getting data: 2017-12-14 to 2017-12-21
# Period 2017-12-14: 151 approaches
#  Getting data: 2017-12-21 to 2017-12-28
# Period 2017-12-21: 148 approaches
#  Getting data: 2017-12-28 to 2018-01-04
# Period 2017-12-28: 120 approaches
#  Getting data: 2018-01-04 to 2018-01-11
# Period 2018-01-04: 109 approaches
#  Getting data: 2018-01-11 to 2018-01-18
# Period 2018-01-11: 129 approaches
#  Getting data: 2018-01-18 to 2018-01-25
# Period 2018-01-18: 113 approaches
#  Getting data: 2018-01-25 to 2018-02-01
# Period 2018-01-25: 121 approaches
#  Getting data: 2018-02-01 to 2018-02-08
# Period 2018-02-01: 129 approaches
#  Getting data: 2018-02-08 to 2018-02-15
# Period 2018-02-08: 117 approaches
#  Getting data: 2018-02-15 to 2018-02-22
# Period 2018-02-15: 125 approaches
#  Getting data: 2018-02-22 to 2018-03-01
# Period 2018-02-22: 119 approaches
#  Getting data: 2018-03-01 to 2018-03-08
# Period 2018-03-01: 125 approaches
#  Getting data: 2018-03-08 to 2018-03-15
# Period 2018-03-08: 132 approaches
#  Getting data: 2018-03-15 to 2018-03-22
# Period 2018-03-15: 130 approaches
#  Getting data: 2018-03-22 to 2018-03-29
# Period 2018-03-22: 133 approaches
#  Getting data: 2018-03-29 to 2018-04-05
# Period 2018-03-29: 131 approaches
#  Getting data: 2018-04-05 to 2018-04-12
# Period 2018-04-05: 145 approaches
#  Getting data: 2018-04-12 to 2018-04-19
# Period 2018-04-12: 138 approaches
#  Getting data: 2018-04-19 to 2018-04-26
# Period 2018-04-19: 135 approaches
#  Getting data: 2018-04-26 to 2018-05-03
# Period 2018-04-26: 126 approaches
#  Getting data: 2018-05-03 to 2018-05-10
# Period 2018-05-03: 119 approaches
#  Getting data: 2018-05-10 to 2018-05-17
# Period 2018-05-10: 119 approaches
#  Getting data: 2018-05-17 to 2018-05-24
# Period 2018-05-17: 125 approaches
#  Getting data: 2018-05-24 to 2018-05-31
# Period 2018-05-24: 123 approaches
#  Getting data: 2018-05-31 to 2018-06-07
# Period 2018-05-31: 109 approaches
#  Getting data: 2018-06-07 to 2018-06-14
# Period 2018-06-07: 95 approaches
#  Getting data: 2018-06-14 to 2018-06-21
# Period 2018-06-14: 105 approaches
#  Getting data: 2018-06-21 to 2018-06-28
# Period 2018-06-21: 86 approaches
#  Getting data: 2018-06-28 to 2018-07-05
# Period 2018-06-28: 91 approaches
#  Getting data: 2018-07-05 to 2018-07-12
# Period 2018-07-05: 107 approaches
#  Getting data: 2018-07-12 to 2018-07-19
# Period 2018-07-12: 116 approaches
#  Getting data: 2018-07-19 to 2018-07-26
# Period 2018-07-19: 106 approaches
#  Getting data: 2018-07-26 to 2018-08-02
# Period 2018-07-26: 112 approaches
#  Getting data: 2018-08-02 to 2018-08-09
# Period 2018-08-02: 111 approaches
#  Getting data: 2018-08-09 to 2018-08-16
# Period 2018-08-09: 129 approaches
#  Getting data: 2018-08-16 to 2018-08-23
# Period 2018-08-16: 138 approaches
#  Getting data: 2018-08-23 to 2018-08-30
# Period 2018-08-23: 124 approaches
#  Getting data: 2018-08-30 to 2018-09-06
# Period 2018-08-30: 138 approaches
#  Getting data: 2018-09-06 to 2018-09-13
# Period 2018-09-06: 159 approaches
#  Getting data: 2018-09-13 to 2018-09-20
# Period 2018-09-13: 146 approaches
#  Getting data: 2018-09-20 to 2018-09-27
# Period 2018-09-20: 147 approaches
#  Getting data: 2018-09-27 to 2018-10-04
# Period 2018-09-27: 144 approaches
#  Getting data: 2018-10-04 to 2018-10-11
# Period 2018-10-04: 155 approaches
#  Getting data: 2018-10-11 to 2018-10-18
# Period 2018-10-11: 155 approaches
#  Getting data: 2018-10-18 to 2018-10-25
# Period 2018-10-18: 159 approaches
#  Getting data: 2018-10-25 to 2018-11-01
# Period 2018-10-25: 142 approaches
#  Getting data: 2018-11-01 to 2018-11-08
# Period 2018-11-01: 162 approaches
#  Getting data: 2018-11-08 to 2018-11-15
# Period 2018-11-08: 167 approaches
#  Getting data: 2018-11-15 to 2018-11-22
# Period 2018-11-15: 134 approaches
#  Getting data: 2018-11-22 to 2018-11-29
# Period 2018-11-22: 137 approaches
#  Getting data: 2018-11-29 to 2018-12-06
# Period 2018-11-29: 139 approaches
#  Getting data: 2018-12-06 to 2018-12-13
# Period 2018-12-06: 138 approaches
#  Getting data: 2018-12-13 to 2018-12-20
# Period 2018-12-13: 127 approaches
#  Getting data: 2018-12-20 to 2018-12-27
# Period 2018-12-20: 112 approaches
#  Getting data: 2018-12-27 to 2019-01-03
# Period 2018-12-27: 123 approaches
#  Getting data: 2019-01-03 to 2019-01-10
# Period 2019-01-03: 144 approaches
#  Getting data: 2019-01-10 to 2019-01-17
# Period 2019-01-10: 148 approaches
#  Getting data: 2019-01-17 to 2019-01-24
# Period 2019-01-17: 121 approaches
#  Getting data: 2019-01-24 to 2019-01-31
# Period 2019-01-24: 161 approaches
#  Getting data: 2019-01-31 to 2019-02-07
# Period 2019-01-31: 121 approaches
#  Getting data: 2019-02-07 to 2019-02-14
# Period 2019-02-07: 116 approaches
#  Getting data: 2019-02-14 to 2019-02-21
# Period 2019-02-14: 129 approaches
#  Getting data: 2019-02-21 to 2019-02-28
# Period 2019-02-21: 114 approaches
#  Getting data: 2019-02-28 to 2019-03-07
# Period 2019-02-28: 134 approaches
#  Getting data: 2019-03-07 to 2019-03-14
# Period 2019-03-07: 128 approaches
#  Getting data: 2019-03-14 to 2019-03-21
# Period 2019-03-14: 117 approaches
#  Getting data: 2019-03-21 to 2019-03-28
# Period 2019-03-21: 123 approaches
#  Getting data: 2019-03-28 to 2019-04-04
# Period 2019-03-28: 139 approaches
#  Getting data: 2019-04-04 to 2019-04-11
# Period 2019-04-04: 138 approaches
#  Getting data: 2019-04-11 to 2019-04-18
# Period 2019-04-11: 147 approaches
#  Getting data: 2019-04-18 to 2019-04-25
# Period 2019-04-18: 150 approaches
#  Getting data: 2019-04-25 to 2019-05-02
# Period 2019-04-25: 154 approaches
#  Getting data: 2019-05-02 to 2019-05-09
# Period 2019-05-02: 140 approaches
#  Getting data: 2019-05-09 to 2019-05-16
# Period 2019-05-09: 113 approaches
#  Getting data: 2019-05-16 to 2019-05-23
# Period 2019-05-16: 114 approaches
#  Getting data: 2019-05-23 to 2019-05-30
# Period 2019-05-23: 136 approaches
#  Getting data: 2019-05-30 to 2019-06-06
# Period 2019-05-30: 128 approaches
#  Getting data: 2019-06-06 to 2019-06-13
# Period 2019-06-06: 111 approaches
#  Getting data: 2019-06-13 to 2019-06-20
# Period 2019-06-13: 103 approaches
#  Getting data: 2019-06-20 to 2019-06-27
# Period 2019-06-20: 113 approaches
#  Getting data: 2019-06-27 to 2019-07-04
# Period 2019-06-27: 116 approaches
#  Getting data: 2019-07-04 to 2019-07-11
# Period 2019-07-04: 119 approaches
#  Getting data: 2019-07-11 to 2019-07-18
# Period 2019-07-11: 106 approaches
#  Getting data: 2019-07-18 to 2019-07-25
# Period 2019-07-18: 122 approaches
#  Getting data: 2019-07-25 to 2019-08-01
# Period 2019-07-25: 117 approaches
#  Getting data: 2019-08-01 to 2019-08-08
# Period 2019-08-01: 107 approaches
#  Getting data: 2019-08-08 to 2019-08-15
# Period 2019-08-08: 133 approaches
#  Getting data: 2019-08-15 to 2019-08-22
# Period 2019-08-15: 137 approaches
#  Getting data: 2019-08-22 to 2019-08-29
# Period 2019-08-22: 130 approaches
#  Getting data: 2019-08-29 to 2019-09-05
# Period 2019-08-29: 144 approaches
#  Getting data: 2019-09-05 to 2019-09-12
# Period 2019-09-05: 151 approaches
#  Getting data: 2019-09-12 to 2019-09-19
# Period 2019-09-12: 173 approaches
#  Getting data: 2019-09-19 to 2019-09-26
# Period 2019-09-19: 184 approaches
#  Getting data: 2019-09-26 to 2019-10-03
# Period 2019-09-26: 180 approaches
#  Getting data: 2019-10-03 to 2019-10-10
# Period 2019-10-03: 177 approaches
#  Getting data: 2019-10-10 to 2019-10-17
# Period 2019-10-10: 197 approaches
#  Getting data: 2019-10-17 to 2019-10-24
# Period 2019-10-17: 192 approaches
#  Getting data: 2019-10-24 to 2019-10-31
# Period 2019-10-24: 202 approaches
#  Getting data: 2019-10-31 to 2019-11-07
# Period 2019-10-31: 181 approaches
#  Getting data: 2019-11-07 to 2019-11-14
# Period 2019-11-07: 151 approaches
#  Getting data: 2019-11-14 to 2019-11-21
# Period 2019-11-14: 156 approaches
#  Getting data: 2019-11-21 to 2019-11-28
# Period 2019-11-21: 135 approaches
#  Getting data: 2019-11-28 to 2019-12-05
# Period 2019-11-28: 123 approaches
#  Getting data: 2019-12-05 to 2019-12-12
# Period 2019-12-05: 119 approaches
#  Getting data: 2019-12-12 to 2019-12-19
# Period 2019-12-12: 135 approaches
#  Getting data: 2019-12-19 to 2019-12-26
# Period 2019-12-19: 122 approaches
#  Getting data: 2019-12-26 to 2020-01-02
# Period 2019-12-26: 131 approaches
#  Getting data: 2020-01-02 to 2020-01-09
# Period 2020-01-02: 138 approaches
#  Getting data: 2020-01-09 to 2020-01-16
# Period 2020-01-09: 146 approaches
#  Getting data: 2020-01-16 to 2020-01-23
# Period 2020-01-16: 163 approaches
#  Getting data: 2020-01-23 to 2020-01-30
# Period 2020-01-23: 169 approaches
#  Getting data: 2020-01-30 to 2020-02-06
# Period 2020-01-30: 159 approaches
#  Getting data: 2020-02-06 to 2020-02-13
# Period 2020-02-06: 146 approaches
#  Getting data: 2020-02-13 to 2020-02-20
# Period 2020-02-13: 154 approaches
#  Getting data: 2020-02-20 to 2020-02-27
# Period 2020-02-20: 149 approaches
#  Getting data: 2020-02-27 to 2020-03-05
# Period 2020-02-27: 164 approaches
#  Getting data: 2020-03-05 to 2020-03-12
# Period 2020-03-05: 119 approaches
#  Getting data: 2020-03-12 to 2020-03-19
# Period 2020-03-12: 139 approaches
#  Getting data: 2020-03-19 to 2020-03-26
# Period 2020-03-19: 146 approaches
#  Getting data: 2020-03-26 to 2020-04-02
# Period 2020-03-26: 145 approaches
#  Getting data: 2020-04-02 to 2020-04-09
# Period 2020-04-02: 144 approaches
#  Getting data: 2020-04-09 to 2020-04-16
# Period 2020-04-09: 169 approaches
#  Getting data: 2020-04-16 to 2020-04-23
# Period 2020-04-16: 168 approaches
#  Getting data: 2020-04-23 to 2020-04-30
# Period 2020-04-23: 173 approaches
#  Getting data: 2020-04-30 to 2020-05-07
# Period 2020-04-30: 159 approaches
#  Getting data: 2020-05-07 to 2020-05-14
# Period 2020-05-07: 130 approaches
#  Getting data: 2020-05-14 to 2020-05-21
# Period 2020-05-14: 129 approaches
#  Getting data: 2020-05-21 to 2020-05-28
# Period 2020-05-21: 138 approaches
#  Getting data: 2020-05-28 to 2020-06-04
# Period 2020-05-28: 145 approaches
#  Getting data: 2020-06-04 to 2020-06-11
# Period 2020-06-04: 112 approaches
#  Getting data: 2020-06-11 to 2020-06-18
# Period 2020-06-11: 104 approaches
#  Getting data: 2020-06-18 to 2020-06-25
# Period 2020-06-18: 127 approaches
#  Getting data: 2020-06-25 to 2020-07-02
# Period 2020-06-25: 127 approaches
#  Getting data: 2020-07-02 to 2020-07-09
# Period 2020-07-02: 129 approaches
#  Getting data: 2020-07-09 to 2020-07-16
# Period 2020-07-09: 129 approaches
#  Getting data: 2020-07-16 to 2020-07-23
# Period 2020-07-16: 143 approaches
#  Getting data: 2020-07-23 to 2020-07-30
# Period 2020-07-23: 159 approaches
#  Getting data: 2020-07-30 to 2020-08-06
# Period 2020-07-30: 161 approaches
#  Getting data: 2020-08-06 to 2020-08-13
# Period 2020-08-06: 143 approaches
#  Getting data: 2020-08-13 to 2020-08-20
# Period 2020-08-13: 151 approaches
#  Getting data: 2020-08-20 to 2020-08-27
# Period 2020-08-20: 152 approaches
#  Getting data: 2020-08-27 to 2020-09-03
# Period 2020-08-27: 165 approaches
#  Getting data: 2020-09-03 to 2020-09-10
# Period 2020-09-03: 182 approaches
#  Getting data: 2020-09-10 to 2020-09-17
# Period 2020-09-10: 199 approaches
#  Getting data: 2020-09-17 to 2020-09-24
# Period 2020-09-17: 195 approaches
#  Getting data: 2020-09-24 to 2020-10-01
# Period 2020-09-24: 182 approaches
#  Getting data: 2020-10-01 to 2020-10-08
# Period 2020-10-01: 163 approaches
#  Getting data: 2020-10-08 to 2020-10-15
# Period 2020-10-08: 208 approaches
#  Getting data: 2020-10-15 to 2020-10-22
# Period 2020-10-15: 225 approaches
#  Getting data: 2020-10-22 to 2020-10-29
# Period 2020-10-22: 181 approaches
#  Getting data: 2020-10-29 to 2020-11-05
# Period 2020-10-29: 166 approaches
#  Getting data: 2020-11-05 to 2020-11-12
# Period 2020-11-05: 169 approaches
#  Getting data: 2020-11-12 to 2020-11-19
# Period 2020-11-12: 175 approaches
#  Getting data: 2020-11-19 to 2020-11-26
# Period 2020-11-19: 154 approaches
#  Getting data: 2020-11-26 to 2020-12-03
# Period 2020-11-26: 154 approaches
#  Getting data: 2020-12-03 to 2020-12-10
# Period 2020-12-03: 158 approaches
#  Getting data: 2020-12-10 to 2020-12-17
# Period 2020-12-10: 143 approaches
#  Getting data: 2020-12-17 to 2020-12-24
# Period 2020-12-17: 162 approaches
#  Getting data: 2020-12-24 to 2020-12-31
# Period 2020-12-24: 140 approaches
#  Getting data: 2020-12-31 to 2021-01-07
# Period 2020-12-31: 154 approaches
#  Getting data: 2021-01-07 to 2021-01-14
# Period 2021-01-07: 165 approaches
#  Getting data: 2021-01-14 to 2021-01-21
# Period 2021-01-14: 149 approaches
#  Getting data: 2021-01-21 to 2021-01-28
# Period 2021-01-21: 123 approaches
#  Getting data: 2021-01-28 to 2021-02-04
# Period 2021-01-28: 136 approaches
#  Getting data: 2021-02-04 to 2021-02-11
# Period 2021-02-04: 170 approaches
#  Getting data: 2021-02-11 to 2021-02-18
# Period 2021-02-11: 155 approaches
#  Getting data: 2021-02-18 to 2021-02-25
# Period 2021-02-18: 162 approaches
#  Getting data: 2021-02-25 to 2021-03-04
# Period 2021-02-25: 146 approaches
#  Getting data: 2021-03-04 to 2021-03-11
# Period 2021-03-04: 162 approaches
#  Getting data: 2021-03-11 to 2021-03-18
# Period 2021-03-11: 157 approaches
#  Getting data: 2021-03-18 to 2021-03-25
# Period 2021-03-18: 138 approaches
#  Getting data: 2021-03-25 to 2021-04-01
# Period 2021-03-25: 147 approaches
#  Getting data: 2021-04-01 to 2021-04-08
# Period 2021-04-01: 169 approaches
#  Getting data: 2021-04-08 to 2021-04-15
# Period 2021-04-08: 166 approaches
#  Getting data: 2021-04-15 to 2021-04-22
# Period 2021-04-15: 180 approaches
#  Getting data: 2021-04-22 to 2021-04-29
# Period 2021-04-22: 175 approaches
#  Getting data: 2021-04-29 to 2021-05-06
# Period 2021-04-29: 154 approaches
#  Getting data: 2021-05-06 to 2021-05-13
# Period 2021-05-06: 151 approaches
#  Getting data: 2021-05-13 to 2021-05-20
# Period 2021-05-13: 153 approaches
#  Getting data: 2021-05-20 to 2021-05-27
# Period 2021-05-20: 146 approaches
#  Getting data: 2021-05-27 to 2021-06-03
# Period 2021-05-27: 141 approaches
#  Getting data: 2021-06-03 to 2021-06-10
# Period 2021-06-03: 141 approaches
#  Getting data: 2021-06-10 to 2021-06-17
# Period 2021-06-10: 133 approaches
#  Getting data: 2021-06-17 to 2021-06-24
# Period 2021-06-17: 136 approaches
#  Getting data: 2021-06-24 to 2021-07-01
# Period 2021-06-24: 128 approaches
#  Getting data: 2021-07-01 to 2021-07-08
# Period 2021-07-01: 121 approaches
#  Getting data: 2021-07-08 to 2021-07-15
# Period 2021-07-08: 117 approaches
#  Getting data: 2021-07-15 to 2021-07-22
# Period 2021-07-15: 129 approaches
#  Getting data: 2021-07-22 to 2021-07-29
# Period 2021-07-22: 130 approaches
#  Getting data: 2021-07-29 to 2021-08-05
# Period 2021-07-29: 152 approaches
#  Getting data: 2021-08-05 to 2021-08-12
# Period 2021-08-05: 132 approaches
#  Getting data: 2021-08-12 to 2021-08-19
# Period 2021-08-12: 126 approaches
#  Getting data: 2021-08-19 to 2021-08-26
# Period 2021-08-19: 181 approaches
#  Getting data: 2021-08-26 to 2021-09-02
# Period 2021-08-26: 155 approaches
#  Getting data: 2021-09-02 to 2021-09-09
# Period 2021-09-02: 202 approaches
#  Getting data: 2021-09-09 to 2021-09-16
# Period 2021-09-09: 224 approaches
#  Getting data: 2021-09-16 to 2021-09-23
# Period 2021-09-16: 192 approaches
#  Getting data: 2021-09-23 to 2021-09-30
# Period 2021-09-23: 172 approaches
#  Getting data: 2021-09-30 to 2021-10-07
# Period 2021-09-30: 177 approaches
#  Getting data: 2021-10-07 to 2021-10-14
# Period 2021-10-07: 197 approaches
#  Getting data: 2021-10-14 to 2021-10-21
# Period 2021-10-14: 203 approaches
#  Getting data: 2021-10-21 to 2021-10-28
# Period 2021-10-21: 186 approaches
#  Getting data: 2021-10-28 to 2021-11-04
# Period 2021-10-28: 206 approaches
#  Getting data: 2021-11-04 to 2021-11-11
# Period 2021-11-04: 213 approaches
#  Getting data: 2021-11-11 to 2021-11-18
# Period 2021-11-11: 168 approaches
#  Getting data: 2021-11-18 to 2021-11-25
# Period 2021-11-18: 161 approaches
#  Getting data: 2021-11-25 to 2021-12-02
# Period 2021-11-25: 176 approaches
#  Getting data: 2021-12-02 to 2021-12-09
# Period 2021-12-02: 185 approaches
#  Getting data: 2021-12-09 to 2021-12-16
# Period 2021-12-09: 144 approaches
#  Getting data: 2021-12-16 to 2021-12-23
# Period 2021-12-16: 119 approaches
#  Getting data: 2021-12-23 to 2021-12-30
# Period 2021-12-23: 131 approaches
#  Getting data: 2021-12-30 to 2022-01-06
# Period 2021-12-30: 127 approaches
#  Getting data: 2022-01-06 to 2022-01-13
# Period 2022-01-06: 146 approaches
#  Getting data: 2022-01-13 to 2022-01-20
# Period 2022-01-13: 150 approaches
#  Getting data: 2022-01-20 to 2022-01-27
# Period 2022-01-20: 158 approaches
#  Getting data: 2022-01-27 to 2022-02-03
# Period 2022-01-27: 175 approaches
#  Getting data: 2022-02-03 to 2022-02-10
# Period 2022-02-03: 175 approaches
#  Getting data: 2022-02-10 to 2022-02-17
# Period 2022-02-10: 145 approaches
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# Error in period 2022-02-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-02-17&end_date=2022-02-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-02-17 to 2022-02-24
# ...
#  Getting data: 2022-03-03 to 2022-03-10
# Error in period 2022-03-03: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-03-03&end_date=2022-03-10&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-03-03 to 2022-03-10
# Period 2022-03-03: 167 approaches
#  Getting data: 2022-03-10 to 2022-03-17
# Period 2022-03-10: 152 approaches
#  Getting data: 2022-03-17 to 2022-03-24
# Error in period 2022-03-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-03-17&end_date=2022-03-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-03-17 to 2022-03-24
# Error in period 2022-03-17: HTTPSConnectionPool(host='api.nasa.gov', port=443): Max retries exceeded with url: /neo/rest/v1/feed?start_date=2022-03-17&end_date=2022-03-24&api_key=3tVIswJxyt5z8MXgJIVpfVgCKXce5iwtOUlfCS7y (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'api.nasa.gov'. (_ssl.c:1007)")))
#  Getting data: 2022-03-17 to 2022-03-24
# Period 2022-03-17: 135 approaches
#  Getting data: 2022-03-24 to 2022-03-31
# Period 2022-03-24: 175 approaches
#  Getting data: 2022-03-31 to 2022-04-07
# Period 2022-03-31: 172 approaches
#  Getting data: 2022-04-07 to 2022-04-14
# Period 2022-04-07: 147 approaches
#  Getting data: 2022-04-14 to 2022-04-21
# Period 2022-04-14: 144 approaches
#  Getting data: 2022-04-21 to 2022-04-28
# Period 2022-04-21: 139 approaches
#  Getting data: 2022-04-28 to 2022-05-05
# Period 2022-04-28: 172 approaches
#  Getting data: 2022-05-05 to 2022-05-12
# Period 2022-05-05: 134 approaches
#  Getting data: 2022-05-12 to 2022-05-19
# Period 2022-05-12: 136 approaches
#  Getting data: 2022-05-19 to 2022-05-26
# Period 2022-05-19: 129 approaches
#  Getting data: 2022-05-26 to 2022-06-02
# Period 2022-05-26: 143 approaches
#  Getting data: 2022-06-02 to 2022-06-09
# Period 2022-06-02: 130 approaches
#  Getting data: 2022-06-09 to 2022-06-16
# Period 2022-06-09: 119 approaches
#  Getting data: 2022-06-16 to 2022-06-23
# Period 2022-06-16: 115 approaches
#  Getting data: 2022-06-23 to 2022-06-30
# Period 2022-06-23: 123 approaches
#  Getting data: 2022-06-30 to 2022-07-07
# Period 2022-06-30: 120 approaches
#  Getting data: 2022-07-07 to 2022-07-14
# Period 2022-07-07: 128 approaches
#  Getting data: 2022-07-14 to 2022-07-21
# Period 2022-07-14: 121 approaches
#  Getting data: 2022-07-21 to 2022-07-28
# Period 2022-07-21: 123 approaches
#  Getting data: 2022-07-28 to 2022-08-04
# Period 2022-07-28: 123 approaches
#  Getting data: 2022-08-04 to 2022-08-11
# Period 2022-08-04: 138 approaches
#  Getting data: 2022-08-11 to 2022-08-18
# Period 2022-08-11: 152 approaches
#  Getting data: 2022-08-18 to 2022-08-25
# Period 2022-08-18: 149 approaches
#  Getting data: 2022-08-25 to 2022-09-01
# Period 2022-08-25: 166 approaches
#  Getting data: 2022-09-01 to 2022-09-08
# Period 2022-09-01: 144 approaches
#  Getting data: 2022-09-08 to 2022-09-15
# Period 2022-09-08: 172 approaches
#  Getting data: 2022-09-15 to 2022-09-22
# Period 2022-09-15: 207 approaches
#  Getting data: 2022-09-22 to 2022-09-29
# Period 2022-09-22: 205 approaches
#  Getting data: 2022-09-29 to 2022-10-06
# Period 2022-09-29: 214 approaches
#  Getting data: 2022-10-06 to 2022-10-13
# Period 2022-10-06: 189 approaches
#  Getting data: 2022-10-13 to 2022-10-20
# Period 2022-10-13: 204 approaches
#  Getting data: 2022-10-20 to 2022-10-27
# Period 2022-10-20: 260 approaches
#  Getting data: 2022-10-27 to 2022-11-03
# Period 2022-10-27: 216 approaches
#  Getting data: 2022-11-03 to 2022-11-10
# Period 2022-11-03: 190 approaches
#  Getting data: 2022-11-10 to 2022-11-17
# Period 2022-11-10: 152 approaches
#  Getting data: 2022-11-17 to 2022-11-24
# Period 2022-11-17: 199 approaches
#  Getting data: 2022-11-24 to 2022-12-01
# Period 2022-11-24: 169 approaches
#  Getting data: 2022-12-01 to 2022-12-08
# Period 2022-12-01: 155 approaches
#  Getting data: 2022-12-08 to 2022-12-15
# Period 2022-12-08: 137 approaches
#  Getting data: 2022-12-15 to 2022-12-22
# Period 2022-12-15: 151 approaches
#  Getting data: 2022-12-22 to 2022-12-29
# Period 2022-12-22: 156 approaches
#  Getting data: 2022-12-29 to 2023-01-05
# Period 2022-12-29: 123 approaches
#  Getting data: 2023-01-05 to 2023-01-12
# Period 2023-01-05: 132 approaches
#  Getting data: 2023-01-12 to 2023-01-19
# Period 2023-01-12: 122 approaches
#  Getting data: 2023-01-19 to 2023-01-26
# Period 2023-01-19: 144 approaches
#  Getting data: 2023-01-26 to 2023-02-02
# Period 2023-01-26: 141 approaches
#  Getting data: 2023-02-02 to 2023-02-09
# Period 2023-02-02: 146 approaches
#  Getting data: 2023-02-09 to 2023-02-16
# Period 2023-02-09: 168 approaches
#  Getting data: 2023-02-16 to 2023-02-23
# Period 2023-02-16: 127 approaches
#  Getting data: 2023-02-23 to 2023-03-02
# Period 2023-02-23: 135 approaches
#  Getting data: 2023-03-02 to 2023-03-09
# Period 2023-03-02: 168 approaches
#  Getting data: 2023-03-09 to 2023-03-16
# Period 2023-03-09: 148 approaches
#  Getting data: 2023-03-16 to 2023-03-23
# Period 2023-03-16: 175 approaches
#  Getting data: 2023-03-23 to 2023-03-30
# Period 2023-03-23: 164 approaches
#  Getting data: 2023-03-30 to 2023-04-06
# Period 2023-03-30: 177 approaches
#  Getting data: 2023-04-06 to 2023-04-13
# Period 2023-04-06: 170 approaches
#  Getting data: 2023-04-13 to 2023-04-20
# Period 2023-04-13: 160 approaches
#  Getting data: 2023-04-20 to 2023-04-27
# Period 2023-04-20: 158 approaches
#  Getting data: 2023-04-27 to 2023-05-04
# Period 2023-04-27: 147 approaches
#  Getting data: 2023-05-04 to 2023-05-11
# Period 2023-05-04: 136 approaches
#  Getting data: 2023-05-11 to 2023-05-18
# Period 2023-05-11: 136 approaches
#  Getting data: 2023-05-18 to 2023-05-25
# Period 2023-05-18: 164 approaches
#  Getting data: 2023-05-25 to 2023-06-01
# Period 2023-05-25: 142 approaches
#  Getting data: 2023-06-01 to 2023-06-08
# Period 2023-06-01: 120 approaches
#  Getting data: 2023-06-08 to 2023-06-15
# Period 2023-06-08: 124 approaches
#  Getting data: 2023-06-15 to 2023-06-22
# Period 2023-06-15: 116 approaches
#  Getting data: 2023-06-22 to 2023-06-29
# Period 2023-06-22: 119 approaches
#  Getting data: 2023-06-29 to 2023-07-06
# Period 2023-06-29: 99 approaches
#  Getting data: 2023-07-06 to 2023-07-13
# Period 2023-07-06: 108 approaches
#  Getting data: 2023-07-13 to 2023-07-20
# Period 2023-07-13: 125 approaches
#  Getting data: 2023-07-20 to 2023-07-27
# Period 2023-07-20: 126 approaches
#  Getting data: 2023-07-27 to 2023-08-03
# Period 2023-07-27: 121 approaches
#  Getting data: 2023-08-03 to 2023-08-10
# Period 2023-08-03: 125 approaches
#  Getting data: 2023-08-10 to 2023-08-17
# Period 2023-08-10: 154 approaches
#  Getting data: 2023-08-17 to 2023-08-24
# Period 2023-08-17: 138 approaches
#  Getting data: 2023-08-24 to 2023-08-31
# Period 2023-08-24: 162 approaches
#  Getting data: 2023-08-31 to 2023-09-07
# Period 2023-08-31: 176 approaches
#  Getting data: 2023-09-07 to 2023-09-14
# Period 2023-09-07: 213 approaches
#  Getting data: 2023-09-14 to 2023-09-21
# Period 2023-09-14: 211 approaches
#  Getting data: 2023-09-21 to 2023-09-28
# Period 2023-09-21: 211 approaches
#  Getting data: 2023-09-28 to 2023-10-05
# Period 2023-09-28: 207 approaches
#  Getting data: 2023-10-05 to 2023-10-12
# Period 2023-10-05: 216 approaches
#  Getting data: 2023-10-12 to 2023-10-19
# Period 2023-10-12: 235 approaches
#  Getting data: 2023-10-19 to 2023-10-26
# Period 2023-10-19: 217 approaches
#  Getting data: 2023-10-26 to 2023-11-02
# Period 2023-10-26: 188 approaches
#  Getting data: 2023-11-02 to 2023-11-09
# Period 2023-11-02: 187 approaches
#  Getting data: 2023-11-09 to 2023-11-16
# Period 2023-11-09: 169 approaches
#  Getting data: 2023-11-16 to 2023-11-23
# Period 2023-11-16: 170 approaches
#  Getting data: 2023-11-23 to 2023-11-30
# Period 2023-11-23: 150 approaches
#  Getting data: 2023-11-30 to 2023-12-07
# Period 2023-11-30: 169 approaches
#  Getting data: 2023-12-07 to 2023-12-14
# Period 2023-12-07: 172 approaches
#  Getting data: 2023-12-14 to 2023-12-21
# Period 2023-12-14: 160 approaches
#  Getting data: 2023-12-21 to 2023-12-28
# Period 2023-12-21: 122 approaches
#  Getting data: 2023-12-28 to 2024-01-04
# Period 2023-12-28: 126 approaches
#  Getting data: 2024-01-04 to 2024-01-11
# Period 2024-01-04: 141 approaches
#  Getting data: 2024-01-11 to 2024-01-18
# Period 2024-01-11: 146 approaches
#  Getting data: 2024-01-18 to 2024-01-25
# Period 2024-01-18: 141 approaches
#  Getting data: 2024-01-25 to 2024-02-01
# Period 2024-01-25: 154 approaches
#  Getting data: 2024-02-01 to 2024-02-08
# Period 2024-02-01: 171 approaches
#  Getting data: 2024-02-08 to 2024-02-15
# Period 2024-02-08: 133 approaches
#  Getting data: 2024-02-15 to 2024-02-22
# Period 2024-02-15: 161 approaches
#  Getting data: 2024-02-22 to 2024-02-29
# Period 2024-02-22: 131 approaches
#  Getting data: 2024-02-29 to 2024-03-07
# Period 2024-02-29: 151 approaches
#  Getting data: 2024-03-07 to 2024-03-14
# Period 2024-03-07: 124 approaches
#  Getting data: 2024-03-14 to 2024-03-21
# Period 2024-03-14: 142 approaches
#  Getting data: 2024-03-21 to 2024-03-28
# Period 2024-03-21: 130 approaches
#  Getting data: 2024-03-28 to 2024-04-04
# Period 2024-03-28: 147 approaches
#  Getting data: 2024-04-04 to 2024-04-11
# Period 2024-04-04: 166 approaches
#  Getting data: 2024-04-11 to 2024-04-18
# Period 2024-04-11: 184 approaches
#  Getting data: 2024-04-18 to 2024-04-25
# Period 2024-04-18: 147 approaches
#  Getting data: 2024-04-25 to 2024-05-02
# Period 2024-04-25: 163 approaches
#  Getting data: 2024-05-02 to 2024-05-09
# Period 2024-05-02: 157 approaches
#  Getting data: 2024-05-09 to 2024-05-16
# Period 2024-05-09: 139 approaches
#  Getting data: 2024-05-16 to 2024-05-23
# Period 2024-05-16: 113 approaches
#  Getting data: 2024-05-23 to 2024-05-30
# Period 2024-05-23: 123 approaches
#  Getting data: 2024-05-30 to 2024-06-06
# Period 2024-05-30: 125 approaches
#  Getting data: 2024-06-06 to 2024-06-13
# Period 2024-06-06: 112 approaches
#  Getting data: 2024-06-13 to 2024-06-20
# Period 2024-06-13: 111 approaches
#  Getting data: 2024-06-20 to 2024-06-27
# Period 2024-06-20: 112 approaches
#  Getting data: 2024-06-27 to 2024-07-04
# Period 2024-06-27: 129 approaches
#  Getting data: 2024-07-04 to 2024-07-11
# Period 2024-07-04: 117 approaches
#  Getting data: 2024-07-11 to 2024-07-18
# Period 2024-07-11: 104 approaches
#  Getting data: 2024-07-18 to 2024-07-25
# Period 2024-07-18: 101 approaches
#  Getting data: 2024-07-25 to 2024-08-01
# Period 2024-07-25: 118 approaches
#  Getting data: 2024-08-01 to 2024-08-08
# Period 2024-08-01: 140 approaches
#  Getting data: 2024-08-08 to 2024-08-15
# Period 2024-08-08: 129 approaches
#  Getting data: 2024-08-15 to 2024-08-22
# Period 2024-08-15: 121 approaches
#  Getting data: 2024-08-22 to 2024-08-29
# Period 2024-08-22: 155 approaches
#  Getting data: 2024-08-29 to 2024-09-05
# Period 2024-08-29: 164 approaches
#  Getting data: 2024-09-05 to 2024-09-12
# Period 2024-09-05: 188 approaches
#  Getting data: 2024-09-12 to 2024-09-19
# Period 2024-09-12: 170 approaches
#  Getting data: 2024-09-19 to 2024-09-26
# Period 2024-09-19: 200 approaches
#  Getting data: 2024-09-26 to 2024-10-03
# Period 2024-09-26: 201 approaches
#  Getting data: 2024-10-03 to 2024-10-10
# Period 2024-10-03: 248 approaches
#  Getting data: 2024-10-10 to 2024-10-17
# Period 2024-10-10: 184 approaches
#  Getting data: 2024-10-17 to 2024-10-24
# Period 2024-10-17: 185 approaches
#  Getting data: 2024-10-24 to 2024-10-31
# Period 2024-10-24: 195 approaches
#  Getting data: 2024-10-31 to 2024-11-07
# Period 2024-10-31: 158 approaches
#  Getting data: 2024-11-07 to 2024-11-14
# Period 2024-11-07: 162 approaches
#  Getting data: 2024-11-14 to 2024-11-21
# Period 2024-11-14: 166 approaches
#  Getting data: 2024-11-21 to 2024-11-28
# Period 2024-11-21: 163 approaches
#  Getting data: 2024-11-28 to 2024-12-05
# Period 2024-11-28: 181 approaches
#  Getting data: 2024-12-05 to 2024-12-12
# Period 2024-12-05: 148 approaches
#  Getting data: 2024-12-12 to 2024-12-19
# Period 2024-12-12: 138 approaches
#  Getting data: 2024-12-19 to 2024-12-26
# Period 2024-12-19: 150 approaches
#  Getting data: 2024-12-26 to 2025-01-02
# Period 2024-12-26: 161 approaches
#  Getting data: 2025-01-02 to 2025-01-09
# Period 2025-01-02: 125 approaches
#  Getting data: 2025-01-09 to 2025-01-16
# Period 2025-01-09: 124 approaches
#  Getting data: 2025-01-16 to 2025-01-23
# Period 2025-01-16: 137 approaches
#  Getting data: 2025-01-23 to 2025-01-30
# Period 2025-01-23: 110 approaches
#  Getting data: 2025-01-30 to 2025-02-06
# Period 2025-01-30: 138 approaches
#  Getting data: 2025-02-06 to 2025-02-13
# Period 2025-02-06: 109 approaches
#  Getting data: 2025-02-13 to 2025-02-20
# Period 2025-02-13: 145 approaches
#  Getting data: 2025-02-20 to 2025-02-27
# Period 2025-02-20: 155 approaches
#  Getting data: 2025-02-27 to 2025-03-06
# Period 2025-02-27: 140 approaches
#  Getting data: 2025-03-06 to 2025-03-13
# Period 2025-03-06: 139 approaches
#  Getting data: 2025-03-13 to 2025-03-20
# Period 2025-03-13: 136 approaches
#  Getting data: 2025-03-20 to 2025-03-27
# Period 2025-03-20: 142 approaches
#  Getting data: 2025-03-27 to 2025-04-03
# Period 2025-03-27: 139 approaches
#  Getting data: 2025-04-03 to 2025-04-10
# Period 2025-04-03: 117 approaches
#  Getting data: 2025-04-10 to 2025-04-17
# Period 2025-04-10: 115 approaches
#  Getting data: 2025-04-17 to 2025-04-24
# Period 2025-04-17: 151 approaches
#  Getting data: 2025-04-24 to 2025-05-01
# Period 2025-04-24: 143 approaches
#  Getting data: 2025-05-01 to 2025-05-08
# Period 2025-05-01: 118 approaches
#  Getting data: 2025-05-08 to 2025-05-15
# Period 2025-05-08: 106 approaches
#  Getting data: 2025-05-15 to 2025-05-22
# Period 2025-05-15: 119 approaches
#  Getting data: 2025-05-22 to 2025-05-29
# Period 2025-05-22: 112 approaches
#  Getting data: 2025-05-29 to 2025-06-05
# Period 2025-05-29: 101 approaches
#  Getting data: 2025-06-05 to 2025-06-12
# Period 2025-06-05: 90 approaches
#  Getting data: 2025-06-12 to 2025-06-19
# Period 2025-06-12: 97 approaches
#  Getting data: 2025-06-19 to 2025-06-26
# Period 2025-06-19: 104 approaches
#  Getting data: 2025-06-26 to 2025-07-03
# Period 2025-06-26: 93 approaches
#  Getting data: 2025-07-03 to 2025-07-10
# Period 2025-07-03: 106 approaches
#  Getting data: 2025-07-10 to 2025-07-17
# Period 2025-07-10: 111 approaches
#  Getting data: 2025-07-17 to 2025-07-24
# Period 2025-07-17: 105 approaches
#  Getting data: 2025-07-24 to 2025-07-31
# Period 2025-07-24: 112 approaches
#  Getting data: 2025-07-31 to 2025-08-07
# Period 2025-07-31: 118 approaches
#  Getting data: 2025-08-07 to 2025-08-14
# Period 2025-08-07: 124 approaches
#  Getting data: 2025-08-14 to 2025-08-21
# Period 2025-08-14: 128 approaches
#  Getting data: 2025-08-21 to 2025-08-28
# Period 2025-08-21: 147 approaches
#  Getting data: 2025-08-28 to 2025-09-04
# Period 2025-08-28: 143 approaches
#  Getting data: 2025-09-04 to 2025-09-11
# Period 2025-09-04: 135 approaches
#  Getting data: 2025-09-11 to 2025-09-18
# Period 2025-09-11: 149 approaches
#  Getting data: 2025-09-18 to 2025-09-25
# Period 2025-09-18: 168 approaches
#  Getting data: 2025-09-25 to 2025-10-02
# Period 2025-09-25: 172 approaches
#  Getting data: 2025-10-02 to 2025-10-05
# Period 2025-10-02: 76 approaches
#
# EXTRACTION COMPLETED:
#    • Total periods processed: 522
#    • Total unique approaches: 73832
#
# Processing 73832 approaches...
# Historical DataFrame created with 73832 rows and 29 columns
# Dataset saved in: asteroids_10_years_20251005_1426.csv
# File size: 29.91 MB
# Dimensions: 73,832 rows × 29 columns
#
# DATABASE SUCCESSFULLY CREATED!
# File: asteroids_10_years_20251005_1426.csv
# Total approaches: 73,832
# Period covered: 2015-10-08 00:00:00 to 2025-10-05 00:00:00
